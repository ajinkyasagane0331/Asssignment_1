# %% [markdown]
# Q1. Copilot was used to scan the Excel dataset and identify missing values in the Region, Category, Units Sold, and Unit Price columns, where both categorical and numeric data had blanks that could impact analysis.
#
# Q2. Using Copilot, missing values in the Region and Category columns were filled by replacing blank cells with the most frequently occurring value (mode) in each column.
#
# Q3. Copilot filled missing numeric values in the Units Sold and Unit Price columns using the average (mean) of the respective columns to ensure accurate calculations.
#
# Q4. A new calculated column named Total Revenue was created using the formula Units Sold × Unit Price to calculate sales value for each order.
#
# Q5. Copilot calculated the total price for Order ID ORD0123 by multiplying Units Sold (46) and Unit Price (344.55), giving a total revenue of 15,849.30.
#
# Q6. Copilot generated a summary chart showing the average profit by region, making it easy to compare profitability across different regions.
#
# Q7. A pivot table was created to summarize total sales by category and region, with Category as rows, Region as columns, and Total Revenue as values.
#
# Q8. Copilot was used to build a dashboard combining key KPIs such as Total Revenue, Total Orders, and Average Profit, along with charts and pivot tables for overall analysis.
#
# Q9. Copilot generated a summary report describing the data cleaning process, handling of missing values, key sales trends, and regional performance insights.
