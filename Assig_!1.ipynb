# %% [markdown]
#  Q.1) What is Relative Reference
#  Changes when you copy the formula.
# Used when the formula logic should move with the cell.
# Q1.2) Absolute Reference
# --> Does not change when copied.
# Q2) Write a formula to calculate the total sales of Car and Bicyle only only.
# --> Formula =SUMIF(A1:A3,"Car",B1:B3)+SUMIF(A1:A3,"Bicycle",B1:B3)
# Q3)Using the data below, write a formula to calculate the average sales of items priced above 100 but less than 300
# --> =AVERAGEIFS(C2:C4, B2:B4,">100",B2:B4,"<300"
# Q4) Count how many customer names are recorded.
# --> =count(b2:b51) Total is 50
# Q5)Calculate the Total Sales for each row using a formula.
# --> Formula =E2*F2 then drag to do the same operation
# Q6)Calculate the total sales of Notebooks in the North region only.
# --> =SUMIFS(h2:h51, D2:D51, "Notebook", C2:C51, "North") Where we have created new coloum for total sales that is h column
# O7) Create a new coloum for total sale
# --> already created , h column  for total sales
# Q8)insert a line chart showing daily sales trend.
