# %% [markdown]
# Q1--> =IF(B2>=40,"Pass","Fail")
# Q2--> =IF((B2:B5>40000)*(C2,C5>=90),"BONOUS","NO B")
# Q3--> =IF(B2:B6>90,"a",IF(B2:B6>75,"B",IF(B2:B6>50),"C","FAIL")))
# Q4--> =VLOOKUP(E103,A2:C4,1,FALSE)
# O5--> =VLOOKUP(45000,A2:C4,TRUE)
#
# Q6-->=IF(B2:B4>C2:C4,"Exceeded","NOT E")
# Q7
# Q8--> =XLOOKUP("E303",A2:A5,B3:B5)
