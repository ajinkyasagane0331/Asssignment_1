# %%
Q1. Data cleaning Fixing or removing wrong, missing, or messy data. It matters because clean data gives correct results. Dirty data leads to wrong decisions. Steps: remove duplicates, fix errors, fill/remove missing values, standardize formats

Q2. Sorting data--> Select the table Go to Data → Sort Sort by Department A-Z Add level sort by Salary High to Low

Q3. Text functions--> Trim: removes extra spaces Left: takes text from start Rigth: takes text from end Mid: takes text from middle Conct: joins text together

Q4. TODAY() function Gives today’s date automatically. Used to calculate age, deadlines, and time differences.

Q5. Data Validation (Quantity: 1–10, whole numbers) Select the Quantity column Go to Data → Data Validation Allow: Whole number Data: Between Minimum: 1 Maximum: 10 Open Input Message tab Message: Please enter a whole number between 1 and 10. Open Error Alert tab Message: Invalid input! The quantity must be a whole number between 1 and 10

Q6--> First 5 characters from "ExcelTipsAreGreat" =LEFT("ExcelTipsAreGreat",5) Excel Last 4 characters from "DataAnalysis.xlsx" =RIGHT("DataAnalysis.xlsx",4) xlsx Extract "Tips" from "ExcelTipsAreGreat" =MID("ExcelTipsAreGreat",6,4) Tips Count characters in "Hello World!" =LEN("Hello World!") 12

q07--> a) Hello + World =CONCAT("Hello"," ","World") b) Apple, Banana, Cherry =TEXTJOIN(", ",TRUE,"Apple","Banana","Cherry") c) Create 2025: Excel Functions using & ="2025"&": "&"Excel Functions" d) Comma-separated list from A1:A5 =TEXTJOIN(", ",TRUE,A1:A5) e) Full name from A (first) and B (last) into C =A1&" "&B1

o8--> TODAY() date only NOW() date + time b) Days left until 2025-06-10 (date in A1) =A1-TODAY() c) Show current date & time (format) =NOW() (Format cell as MM/DD/YYYY HH:MM AM/PM) d) What happens next day? The date updates automatically e) Static today’s date (no change) Ctrl + ; (semicolon)
